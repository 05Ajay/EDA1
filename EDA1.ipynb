# %%
#load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Tasks:
# 1.Data Cleaning and Preparation:
# Load the dataset into a DataFrame or equivalent data structure.
cardio=pd.read_csv("Cardiotocographic.csv")
cardio
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
cardio.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
# Handle missing values appropriately (e.g., imputation, deletion).
cardio.isna().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
#checking for duplicate values
cardio.duplicated().sum()
# Out:
# 2

# %%
cardio[cardio.duplicated(keep = False)]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1113  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1457  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1113   39.0       0.0  1.0
# 1115   39.0       0.0  1.0
# 1457   35.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
#Dropping Duplicate Records
cardio.drop_duplicates(inplace=True)

# %%
cardio.duplicated().sum()
# Out:
# 0

# %%
# % of missing values
for i in cardio.isna().sum():
 print((i/len(cardio))*100)
  
# 0 to 5 % missing values: drop rows
# 6 to 45 %: replace the missing values
# above 50%: drop column
# Out:
# 0.9887005649717515
# 0.9416195856873822
# 0.0
# 0.0
# 0.0
# 0.9887005649717515
# 0.9887005649717515
# 0.0
# 0.0
# 0.0
# 0.9887005649717515
# 0.9887005649717515
# 0.9887005649717515
# 0.9887005649717515

# %%
cardio.dropna(inplace = True)

# %%
cardio.isna().sum()
#missing values removed
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
# Detect and treat outliers if necessary.
cardio.boxplot()
# Out:
# <Axes: >

# %%
# Iterate through each column in the dataset
for i in cardio.columns:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = cardio[i].quantile(0.25)
    Q3 = cardio[i].quantile(0.75)
    
    # Calculate IQR
    IQR = Q3 - Q1
    
    # Calculate the lower and upper bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Replace outliers with the respective bounds
    cardio.loc[cardio[i] < lower_bound, i] = lower_bound
    cardio.loc[cardio[i] > upper_bound, i] = upper_bound

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=cardio)
# Display the plot
plt.show()

# 1.LB (Left Bundle): 
#    This has a relatively high median value (around 140) compared to the other metrics.
#    The range (from the box and whiskers) indicates some variability, but it's generally more stable.

# 2. AC, FM, UC, DL, DS, DP:
#     These metrics show very low or near-zero median values.
#     There is little to no variability (the boxes are compressed to lines, and whiskers are almost non-existent).

# 3. ASTV (Acceleration of ST segment variance):
#     Has a moderate median value, with some variability as shown by the size of the box and whiskers.

# 4. MSTV (Mean of ST segment variance) and ALTV (Acceleration of Long-Term Variance):
#     Both have small medians but with noticeable variability, suggesting some fluctuation in these values across different samples.

# 5. MLTV (Mean of Long-Term Variance):
#     Similar to ASTV, this shows a small median with some variability.

# 6. Width Tendency:
#     This metric has a significant range, with values extending from negative to very high positive values.
#     The median is positive, but the large range indicates a wide variability in this metric.

# 7. NSP:
#     Similar to AC, FM, UC, DL, DS, and DP, this metric shows a near-zero median with almost no variability.

# %%
# Visualization for LB - Baseline Fetal Heart Rate (FHR) using Histogram(seaborn)
plt.figure(figsize=(10, 6))
sns.histplot(cardio['LB'], bins=20, kde=True)
plt.title('Histogram of Baseline Fetal Heart Rate (FHR)')
plt.xlabel('Baseline Fetal Heart Rate (FHR)')
plt.ylabel('Frequency')
plt.show()

# A baseline FHR between 110 and 160 bpm is generally considered normal during fetal monitoring.
# The histogram shows that the data is concentrated within this range,
# indicating that the majority of the readings fall within the normal range.

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))
correlation = cardio.corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.show()

# - Strong Relationships:
#   - The strong positive correlation between MSTV and MLT suggests that these two variables tend to increase or decrease together.
#   - The negative correlations between ALTV with ASTV and MSTV could indicate that as ALTV increases, ASTV and MSTV decrease, and vice versa.

# - Independent Variables:
#   - Some variables like LB and FM have little to no correlation with the majority of other metrics, suggesting that they may operate independently of the other variables in this dataset.

# %%
# Creating violin plots for each variable
vars_to_plot = ['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV']
plt.figure(figsize=(12, 8))
for i, var in enumerate(vars_to_plot):
    plt.subplot(4, 3, i + 1)
    sns.violinplot(x=cardio[var])
    plt.title(var)
plt.tight_layout()
plt.show()

# %%
# Based on the insights, healthcare providers might adjust their monitoring protocols to focus more on the metrics that show 
# greater variability or stronger correlations with other important metrics.
# This could lead to more efficient and effective patient care.

# %%
# Overall, these findings provide a foundation for refining clinical practices, 
# developing predictive models, and conducting further research to enhance patient care and outcomes
# in cardiographic monitoring.
